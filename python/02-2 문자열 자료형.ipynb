# %% [markdown]
# # 02. 자료형

# %% [markdown]
# ## 02-2 문자열 자료형

# %% [markdown]
# ### 문자열은 어떻게 만들고 사용할까?

# %%
# 1. 큰따옴표로 양쪽 둘러싸기
s = "Hello World"
# 2. 작은따옴표로 양쪽 둘러싸기
s = "Python is fun"
# 3. 큰따옴표 3개를 연속으로 써서 양쪽 둘러싸기
s = """Life is too short, You need python"""
# 4. 작은따옴표 3개를 연속으로 써서 양쪽 둘러싸기
s = """Life is too short, You need python"""

# %% [markdown]
# ### 문자열 안에 작은따옴표나 큰따옴표를 포함시키고 싶을 때

# %% [markdown]
# #### 1. 문자열에 작은따옴표 포함하기

# %%
food = "Python's favorite food is perl"
food
# Out:
# "Python's favorite food is perl"

# %% [markdown]
# #### 2. 문자열에 큰따옴표 포함하기

# %%
say = '"Python is very easy." he says.'
say
# Out:
# '"Python is very easy." he says.'

# %% [markdown]
# #### 3. 역슬래시를 사용해서 작은따옴표와 큰따옴표를 문자열에 포함하기

# %% [markdown]
# 작은따옴표나 큰따옴표를 문자열에 포함시키는 또 다른 방법은 역슬래시(`\`)를 사용하는 것이다. 역슬래시를 작은따옴표나 큰따옴표 앞에 삽입하면 역슬래시 뒤의 작은따옴표나 큰따옴표는 문자열을 둘러싸는 기호가 아니라 문자 그 자체를 뜻한다.

# %%
food = "Python's favorite food is perl"
print(food)
say = '"Python is very easy." he says.'
print(say)
# Out:
# Python's favorite food is perl
# "Python is very easy." he says.

# %% [markdown]
# ### 여러 줄인 문자열을 변수에 대입하고 싶을 때

# %% [markdown]
# Life is too short<br>
# You need python

# %% [markdown]
# #### 1. 줄을 바꾸기 위한 이스케이프 코드 \n 삽입하기

# %%
multiline = "Life is too short\nYou need python"
print(multiline)
# Out:
# Life is too short
# You need python

# %% [markdown]
# #### 2. 연속된 작은따옴표 3개 또는 큰따옴표 3개 사용하기

# %%
multiline = """
Life is too short
You need python
"""
print(multiline)

multiline = """
Life is too short
You need python
"""
print(multiline)
# Out:
# Life is too short
# You need python
#
#
# Life is too short
# You need python

# %% [markdown]
# 문자열 예제에서 여러 줄의 문장을 처리할 때 역슬래시 문자와 소문자 n을 조합한 `\n` 이스케이프 코드를 사용했다. 이스케이프(escape) 코드란 프로그래밍할 때 사용할 수 있도록 미리 정의해 둔 '문자 조합'이다. 주로 출력물을 보기 좋게 정렬하는 용도로 사용한다. 몇 가지 이스케이프 코드를 정리하면 다음과 같다.

# %% [markdown]
# | Code   | 설명                                             |
# | ------ | ------------------------------------------------ |
# | `\n`   | 문자열에 줄바꿈을 삽입할 때 사용                 |
# | `\t`   | 문자열에 탭(들여쓰기) 공백을 삽입할 때 사용      |
# | `\\`   | 리터럴 백슬래시(`\`)를 나타낼 때 사용            |
# | `\'`   | 리터럴 작은따옴표(`'`)를 나타낼 때 사용          |
# | `\"`   | 리터럴 큰따옴표(`"`)를 나타낼 때 사용            |
# | `\r`   | 캐리지 리턴(커서를 현재 줄의 처음으로 이동)      |
# | `\f`   | 폼 피드(커서를 다음 줄로 이동)                   |
# | `\a`   | 벨 소리(지원되는 시스템에서 경고음이 날 수 있음) |
# | `\b`   | 백스페이스                                       |
# | `\000` | 널 문자                                          |

# %% [markdown]
# ### 문자열 연산하기

# %% [markdown]
# #### 문자열 더해서 연결하기

# %%
head = "Python"
tail = " is fun!"
head + tail
# Out:
# 'Python is fun!'

# %% [markdown]
# #### 문자열 곱하기

# %%
a = "python"
a * 2
# Out:
# 'pythonpython'

# %% [markdown]
# #### 문자열 곱하기 응용하기

# %%
print("=" * 50)
print("My Program")
print("=" * 50)
# Out:
# ...
# My Program
# ...

# %% [markdown]
# ### 문자열 길이 구하기

# %%
a = "Life is too short"
len(a)
# Out:
# 17

# %% [markdown]
# ### 문자열 인덱싱과 슬라이싱

# %% [markdown]
# #### 문자열 인덱싱

# %%
a = "Life is too short, You need Python"
a[3]
# Out:
# 'e'

# %% [markdown]
# #### 문자열 인덱싱 활용하기

# %%
print("a[-0]: ", a[-0])
print("a[0]: ", a[0])
# Out:
# a[-0]:  L
# a[0]:  L

# %%
a[-1]
# Out:
# 'n'

# %% [markdown]
# #### 문자열 슬라이싱

# %%
a = "Life is too short, You need Python"
b = a[0] + a[1] + a[2] + a[3]
b
# Out:
# 'Life'

# %%
a[0:4]
# Out:
# 'Life'

# %% [markdown]
# #### 문자열을 슬라이싱하는 방법

# %%
a[0:5]
# Out:
# 'Life '

# %%
a[19:]
# Out:
# 'You need Python'

# %%
a[:17]
# Out:
# 'Life is too short'

# %%
a[:]
# Out:
# 'Life is too short, You need Python'

# %%
a[19:-7]
# Out:
# 'You need'

# %% [markdown]
# #### 슬라이싱으로 문자열 나누기

# %%
a = "20230331Rainy"
date = a[:8]
weather = a[8:]
print("date: ", date)
print("weather: ", weather)
# Out:
# date:  20230331
# weather:  Rainy

# %% [markdown]
# 문자열은 요솟값을 바꿀 수 없는 변경 불가능한(immutable) 자료형이다.
#
# ```python
# a = "Pithon"
# a[1] = 'y' # 안 됨
# ```

# %% [markdown]
# ### 문자열 포매팅이란?

# %% [markdown]
# 문자열 안의 특정한 값을 바꿔야 할 경우가 있을 때 이것을 가능하게 해 주는 것이 바로 문자열 포매팅이다.

# %% [markdown]
# ### 문자열 포매팅 따라하기

# %% [markdown]
# #### 1. 숫자 바로 대입

# %%
"I eat %d apples." % 3
# Out:
# 'I eat 3 apples.'

# %% [markdown]
# 위 예제는 문자열 안에 정수 3을 삽입하는 방법을 보여 준다. 문자열 안의 숫자를 넣고 싶은 자리에 `%d` 문자를 넣어 주고 삽입할 숫자 3은 가장 뒤에 있는 `%` 문자 다음에 써 넣었다. 여기에서 `%d`는 '문자열 포맷 코드'라고 부른다.

# %% [markdown]
# #### 2. 문자열 바로 대입

# %%
"I eat %s apples." % "five"
# Out:
# 'I eat five apples.'

# %% [markdown]
# 문자열 안에 또 다른 문자열을 삽입하기 위해 앞에서 사용한 문자열 포맷 코드 `%d`가 아닌 `%s`를 썼다. 숫자를 넣기 위해서는 `%d`, 문자열을 넣기 위해서는 `%s`를 써야 한다.

# %% [markdown]
# #### 3. 숫자 값을 나타내는 변수로 대입

# %%
number = 3
"I eat %d apples." % number
# Out:
# 'I eat 3 apples.'

# %% [markdown]
# 1번처럼 숫자를 바로 대입하든, 위 예제처럼 숫자 값을 나타내는 변수를 대입하든 결과는 같다.

# %% [markdown]
# #### 4. 2개 이상의 값 넣기

# %%
number = 10
day = "three"
"I ate %d apples. so I was sick for %s days." % (number, day)
# Out:
# 'I ate 10 apples. so I was sick for three days.'

# %% [markdown]
# ### 문자열 포맷 코드

# %% [markdown]
# | 코드 | 설명                       |
# | ---- | -------------------------- |
# | `%s` | 문자열(String)             |
# | `%c` | 문자 1개(Character)        |
# | `%d` | 정수(Integer)              |
# | `%f` | 부동소수점(Floating-point) |
# | `%o` | 8진수                      |
# | `%x` | 16진수                     |
# | `%%` | 문자 `%` 자체              |

# %%
"I have %s apples" % 3
# Out:
# 'I have 3 apples'

# %%
"rate is %s" % 3.234
# Out:
# 'rate is 3.234'

# %% [markdown]
# 3을 문자열 안에 삽입하려면 `%d`를 사용해야 하고 3.234를 삽입하려면 `%f`를 사용해야 한다. 하지만 `%s`를 사용하면 `%s`는 자동으로 `%` 뒤에 있는 3이나 3.234와 같은 값을 문자열로 바꾸어 대입한다.

# %% [markdown]
# "Error is %d%%." % 98

# %% [markdown]
# ### 포맷 코드와 숫자 함께 사용하기

# %% [markdown]
# #### 1. 정렬과 공백

# %%
"%10s" % "hi"
# Out:
# '        hi'

# %% [markdown]
# `%10s`는 전체 길이가 10개인 문자열 공간에서 대입되는 값을 오른쪽으로 정렬하고 그 앞의 나머지는 공백으로 남겨 두라는 의미다. <br>
# 반대쪽인 왼쪽 정렬은 `%-10s`가 된다.

# %%
"%-10sjane." % "hi"
# Out:
# 'hi        jane.'

# %% [markdown]
# #### 2. 소수점 표현하기

# %%
"%0.4f" % 3.42134234
# Out:
# '3.4213'

# %% [markdown]
# 3.42134234를 소수점 네 번째 자리까지만 나타내고 싶은 경우에는 위와 같이 작성한다. `%0.4f`에서 '.'는 소수점 포인트, 그 뒤의 숫자 4는 소수점 뒤에 나올 숫자의 개수다. 소수점 포인트 앞의 숫자는 문자열의 전체 길이를 의미하는데, `%0.4f`에서 사용한 숫자 `0`은 길이에 상관하지 않겠다는 의미다. <br>
# `%0.4f`는 0을 생략하여 `%.4f`처럼 사용하기도 한다.

# %%
"%10.4f" % 3.42134234
# Out:
# '    3.4213'

# %% [markdown]
# 위는 숫자 3.42134234를 소수점 네 번째 자리까지만 표시하고 전체 길이가 10개인 문자열 공간에서 오른쪽으로 정렬하는 예를 보여 준다.

# %% [markdown]
# ### format 함수를 사용한 포매팅

# %% [markdown]
# #### 숫자 바로 대입하기

# %%
"I eat {0} apples".format(3)
# Out:
# 'I eat 3 apples'

# %% [markdown]
# #### 문자열 바로 대입하기

# %%
"I eat {0} apples".format("five")
# Out:
# 'I eat five apples'

# %% [markdown]
# #### 숫자 값을 가진 변수로 대입하기

# %%
number = 3
"I eat {0} apples".format(number)
# Out:
# 'I eat 3 apples'

# %% [markdown]
# #### 2개 이상의 값 넣기

# %%
number = 10
day = "three"
"I ate {0} apples. so I was sick for {1} days.".format(number, day)
# Out:
# 'I ate 10 apples. so I was sick for three days.'

# %% [markdown]
# #### 이름으로 넣기

# %%
"I ate {number} apples. so I was sick for {day} days".format(number=10, day=3)
# Out:
# 'I ate 10 apples. so I was sick for 3 days'

# %% [markdown]
# #### 인덱스와 이름을 혼용해서 넣기

# %%
"I ate {0} apples. so I was sick for {day} days.".format(10, day=3)
# Out:
# 'I ate 10 apples. so I was sick for 3 days.'

# %% [markdown]
# #### 왼쪽 정렬

# %%
"{0:<10}".format("hi")
# Out:
# 'hi        '

# %% [markdown]
# #### 오른쪽 정렬

# %%
"{0:>10}".format("hi")
# Out:
# '        hi'

# %% [markdown]
# #### 가운데 정렬

# %%
"{0:^10}".format("hi")
# Out:
# '    hi    '

# %% [markdown]
# #### 공백 채우기

# %%
"{0:=^10}".format("hi")
# Out:
# '====hi===='

# %%
"{0:=<10}".format("hi")
# Out:
# 'hi========'

# %% [markdown]
# #### 소수점 표현하기

# %%
y = 3.42134234
"{0:0.4f}".format(y)
# Out:
# '3.4213'

# %%
"{0:10.4f}".format(y)
# Out:
# '    3.4213'

# %% [markdown]
# #### { 또는 } 문자 표현하기

# %%
"{{ and }}".format()
# Out:
# '{ and }'

# %% [markdown]
# ### f 문자열 포매팅

# %%
name = "홍길동"
age = 30
f"나의 이름은 {name}입니다. 나이는 {age}입니다."
# Out:
# '나의 이름은 홍길동입니다. 나이는 30입니다.'

# %% [markdown]
# f 문자열 포매팅은 위와 같이 name, age와 같은 변숫값을 생성한 후에 그 값을 참조할 수 있다. 또한 f 문자열 포매팅은 표현식을 지원하기 때문에 다음과 같은 것도 가능하다.

# %%
age = 30
f"나는 내년이면 {age + 1}살이 된다."
# Out:
# '나는 내년이면 31살이 된다.'

# %% [markdown]
# 딕셔너리는 f 문자열 포매팅에서 다음과 같이 사용할 수 있다.

# %%
d = {"name": "홍길동", "age": 30}
f'나의 이름은 {d["name"]}입니다. 나이는 {d["age"]}입니다.'
# Out:
# '나의 이름은 홍길동입니다. 나이는 30입니다.'

# %% [markdown]
# 정렬은 다음과 같이 할 수 있다.

# %%
f'{"hi":<10}'  # 왼쪽 정렬
# Out:
# 'hi        '

# %%
f'{"hi":>10}'  # 오른쪽 정렬
# Out:
# '        hi'

# %%
f'{"hi":^10}'  # 가운데 정렬
# Out:
# '    hi    '

# %% [markdown]
# 공백 채우기는 다음과 같이 할 수 있다.

# %%
f"{'hi':=>10}"
# Out:
# '========hi'

# %%
f'{"hi":!<10}'  # 왼쪽 정렬하고 '!' 문자로 공백 채우기
# Out:
# 'hi!!!!!!!!'

# %% [markdown]
# 소수점은 다음과 같이 표현할 수 있다.

# %%
y = 3.42134234
f"{y:0.4f}"
# Out:
# '3.4213'

# %%
f"{y:10.4f}"
# Out:
# '    3.4213'

# %%
f"{{ and }}"
# Out:
# '{ and }'

# %%
f"난 {1500000:,}원이 필요해"
# Out:
# '난 1,500,000원이 필요해'

# %% [markdown]
# ### 문자열 관련 함수들

# %% [markdown]
# #### 문자 개수 세기 - count

# %%
a = "hobby"
a.count("b")
# Out:
# 2

# %% [markdown]
# #### 위치 알려주기 1 - find

# %%
a = "Python is the best choice"
print(a.find("b"))
print(a.find("k"))
# Out:
# 14
# -1

# %% [markdown]
# 만약 찾는 문자나 문자열이 존재하지 않는다면 -1을 반환한다.

# %% [markdown]
# #### 위치 알려주기 2 - index

# %%
a = "Life is too short"
a.index("t")
# Out:
# 8

# %%
a.index("k")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 a.index("k")
#
# ValueError: substring not found

# %% [markdown]
# #### 문자열 삽입 - join

# %%
",".join("abcd")
# Out:
# 'a,b,c,d'

# %% [markdown]
# join 함수는 문자열뿐만 아니라 앞으로 배울 리스트나 튜플도 입력으로 사용할 수 있다.

# %%
",".join(["a", "b", "c", "d"])
# Out:
# 'a,b,c,d'

# %% [markdown]
# #### 소문자를 대문자로 바꾸기 - upper

# %%
a = "hi"
a.upper()
# Out:
# 'HI'

# %% [markdown]
# #### 대문자를 소문자로 바꾸기 - lower

# %%
a = "HI"
a.lower()
# Out:
# 'hi'

# %% [markdown]
# #### 왼쪽 공백 지우기 - lstrip

# %%
a = " hi "
a.lstrip()
# Out:
# 'hi '

# %% [markdown]
# #### 오른쪽 공백 지우기 - rstrip

# %%
a = " hi "
a.rstrip()
# Out:
# ' hi'

# %% [markdown]
# #### 양쪽 공백 지우기 - strip

# %%
a = " hi "
a.strip()
# Out:
# 'hi'

# %% [markdown]
# #### 문자열 바꾸기 - replace

# %%
a = "Life is too short"
a.replace("Life", "Your leg")
# Out:
# 'Your leg is too short'

# %% [markdown]
# #### 문자열 나누기 - split

# %%
a = "Life is too short"
a.split()
# Out:
# ['Life', 'is', 'too', 'short']

# %%
b = "a:b:c:d"
b.split(":")
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# split 함수는 `a.split()`처럼 괄호 안에 아무 값도 넣어 주지 않으면 공백([Space], [Tab], [Enter])을 기준으로 문자열을 나누어 준다. 만약 `b.split(':')`처럼 괄호 안에 특정 값이 있을 경우에는 괄호 안의 값을 구분자로 해서 문자열을 나누어 준다. 이렇게 나눈 값은 리스트에 하나씩 들어간다.

# %% [markdown]
# #### 문자열이 알파벳으로만 구성되어 있는지 확인하기 - isalpha

# %%
s = "Python"
s.isalpha()
# Out:
# True

# %%
s = "Python3"
s.isalpha()
# Out:
# False

# %%
s = "Hello World"
s.isalpha()
# Out:
# False

# %% [markdown]
# #### 문자열이 숫자로만 구성되어 있는지 확인하기 - isdigit

# %%
s = "12345"
s.isdigit()
# Out:
# True

# %%
s = "123 4"
s.isdigit()
# Out:
# False

# %% [markdown]
# #### 문자열이 특정 문자(열)로 시작하는지 확인하기 - starstwith

# %%
s = "Life is too short"
s.startswith("Life")
# Out:
# True

# %%
s.startswith("short")
# Out:
# False

# %% [markdown]
# #### 문자열이 특정 문자(열)로 끝나는지 확인하기 - endswith

# %%
s = "Life is too short"
s.endswith("short")
# Out:
# True

# %%
s.endswith("Life")
# Out:
# False

# %% [markdown]
# > upper 뿐만 아니라 lower, join, lstrip, rstrip, strip, replace, split 함수는 모두 이와 같은 규칙이 적용되어 문자열 자체의 값이 변경되는 것이 아니라 변경된 값을 반환한다는 사실에 주의하자.
